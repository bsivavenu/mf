# %%
import pandas as pd

# %%
df = pd.read_csv('c:/users/HP/Downloads/ELSS LATEST.csv')
df.head()
# Out:
#                                         Fund   mean  Standard Deviation  \
# 0        Aditya Birla Sun Life Tax Relief 96  13.15               13.55
# 1                 Axis Long Term Equity Fund  12.99               12.76
# 2  BOI AXA Tax Advantage Fund - Regular Plan  12.84               15.25
# 3                         DSP Tax Saver Fund  12.55               15.49
# 4              Franklin India Taxshield Fund   8.84               12.24
#
#    Sharpe Ratio  Sortino Ratio  Beta  Alpha  R-Squared Expense Ratio  \
# 0          0.50           0.67  0.88   1.41       0.86          2.27
# 1          0.51           0.71  0.83   1.56       0.86          2.26
# 2          0.42           0.63  0.98   0.53       0.84          3.09
# 3          0.39           0.65  1.04  -0.16       0.93           2.1
# 4          0.20           0.30  0.83  -2.58       0.94          2.08
#
#    1-Year Return    ...        sector1  sector1%     sector2 sector2%  \
# ...

# %%
df.shape
# Out:
# (17, 94)

# %%
df.describe()
# Out:
#             mean  Standard Deviation  Sharpe Ratio  Sortino Ratio       Beta  \
# count  17.000000           17.000000     17.000000      17.000000  17.000000
# mean   12.637647           14.674118      0.422941       0.617059   0.969412
# std     1.734779            1.440816      0.123732       0.169365   0.104431
# min     8.840000           12.240000      0.200000       0.300000   0.830000
# 25%    11.900000           13.550000      0.350000       0.510000   0.880000
# 50%    12.840000           14.860000      0.420000       0.630000   0.980000
# 75%    13.150000           15.490000      0.450000       0.660000   1.020000
# max    16.120000           17.630000      0.710000       0.970000   1.190000
#
#            Alpha  R-Squared  1-Year Return  Net Assets (Cr)  \
# count  17.000000  17.000000      17.000000        17.000000
# mean    0.360588   0.894118      13.518235      2966.877647
# std     1.830473   0.050381       4.996219      4456.780748
# ...

# %%
cols = ['Expense Ratio','Standard Deviation','Sharpe Ratio','Sortino Ratio','Beta','Alpha','R-Squared','mean']

# %%
cc = df[['Expense Ratio','Standard Deviation','Sharpe Ratio','Sortino Ratio','Beta','Alpha','R-Squared','mean']]

# %%
cc.head()
# Out:
#   Expense Ratio  Standard Deviation  Sharpe Ratio  Sortino Ratio  Beta  Alpha  \
# 0          2.27               13.55          0.50           0.67  0.88   1.41
# 1          2.26               12.76          0.51           0.71  0.83   1.56
# 2          3.09               15.25          0.42           0.63  0.98   0.53
# 3           2.1               15.49          0.39           0.65  1.04  -0.16
# 4          2.08               12.24          0.20           0.30  0.83  -2.58
#
#    R-Squared   mean
# 0       0.86  13.15
# 1       0.86  12.99
# 2       0.84  12.84
# 3       0.93  12.55
# 4       0.94   8.84

# %%
cc.shape
# Out:
# (17, 8)

# %%
cc =pd.DataFrame(cc)

# %%
corrmat = cc.corr()
corrmat
# Out:
#                     Standard Deviation  Sharpe Ratio  Sortino Ratio      Beta  \
# Standard Deviation            1.000000     -0.141076      -0.050685  0.970792
# Sharpe Ratio                 -0.141076      1.000000       0.976001 -0.282817
# Sortino Ratio                -0.050685      0.976001       1.000000 -0.193042
# Beta                          0.970792     -0.282817      -0.193042  1.000000
# Alpha                        -0.168073      0.993782       0.976077 -0.320282
# R-Squared                     0.249702     -0.668801      -0.626219  0.472090
# mean                          0.178493      0.945015       0.958925  0.028384
#
#                        Alpha  R-Squared      mean
# Standard Deviation -0.168073   0.249702  0.178493
# Sharpe Ratio        0.993782  -0.668801  0.945015
# Sortino Ratio       0.976077  -0.626219  0.958925
# Beta               -0.320282   0.472090  0.028384
# Alpha               1.000000  -0.714210  0.937806
# ...

# %%
print(corrmat.sort_values(by='mean',axis=1).mean)
# Out:
# <bound method DataFrame.mean of                     R-Squared      Beta  Standard Deviation     Alpha  \
# Standard Deviation   0.249702  0.970792            1.000000 -0.168073
# Sharpe Ratio        -0.668801 -0.282817           -0.141076  0.993782
# Sortino Ratio       -0.626219 -0.193042           -0.050685  0.976077
# Beta                 0.472090  1.000000            0.970792 -0.320282
# Alpha               -0.714210 -0.320282           -0.168073  1.000000
# R-Squared            1.000000  0.472090            0.249702 -0.714210
# mean                -0.580619  0.028384            0.178493  0.937806
#
#                     Sharpe Ratio  Sortino Ratio      mean
# Standard Deviation     -0.141076      -0.050685  0.178493
# Sharpe Ratio            1.000000       0.976001  0.945015
# Sortino Ratio           0.976001       1.000000  0.958925
# Beta                   -0.282817      -0.193042  0.028384
# Alpha                   0.993782       0.976077  0.937806
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(7,7))
sns.heatmap(corrmat,annot=True,vmax=1)
plt.show()

# %%
cc.describe()
# Out:
#        Standard Deviation  Sharpe Ratio  Sortino Ratio       Beta      Alpha  \
# count           17.000000     17.000000      17.000000  17.000000  17.000000
# mean            14.674118      0.422941       0.617059   0.969412   0.360588
# std              1.440816      0.123732       0.169365   0.104431   1.830473
# min             12.240000      0.200000       0.300000   0.830000  -2.580000
# 25%             13.550000      0.350000       0.510000   0.880000  -0.710000
# 50%             14.860000      0.420000       0.630000   0.980000   0.280000
# 75%             15.490000      0.450000       0.660000   1.020000   0.680000
# max             17.630000      0.710000       0.970000   1.190000   4.400000
#
#        R-Squared       mean
# count  17.000000  17.000000
# mean    0.894118  12.637647
# std     0.050381   1.734779
# min     0.790000   8.840000
# 25%     0.860000  11.900000
# 50%     0.900000  12.840000
# 75%     0.930000  13.150000
# max     0.960000  16.120000

# %% [markdown]
# mean is heavily effeected by sortino ratio

# %%
sharpe = df[ (df['Sharpe Ratio']>=(.20)) &   (df['Sharpe Ratio']<=(.71))]
sharpe.head()
# Out:
#                                         Fund   mean  Standard Deviation  \
# 0        Aditya Birla Sun Life Tax Relief 96  13.15               13.55
# 1                 Axis Long Term Equity Fund  12.99               12.76
# 2  BOI AXA Tax Advantage Fund - Regular Plan  12.84               15.25
# 3                         DSP Tax Saver Fund  12.55               15.49
# 4              Franklin India Taxshield Fund   8.84               12.24
#
#    Sharpe Ratio  Sortino Ratio  Beta  Alpha  R-Squared Expense Ratio  \
# 0          0.50           0.67  0.88   1.41       0.86          2.27
# 1          0.51           0.71  0.83   1.56       0.86          2.26
# 2          0.42           0.63  0.98   0.53       0.84          3.09
# 3          0.39           0.65  1.04  -0.16       0.93           2.1
# 4          0.20           0.30  0.83  -2.58       0.94          2.08
#
#    1-Year Return    ...        sector1  sector1%     sector2 sector2%  \
# ...

# %%
cc['Sortino Ratio'].describe()
# Out:
# count    17.000000
# mean      0.617059
# std       0.169365
# min       0.300000
# 25%       0.510000
# 50%       0.630000
# 75%       0.660000
# max       0.970000
# Name: Sortino Ratio, dtype: float64

# %%
sortino = sharpe[ (sharpe['Sortino Ratio']>=(.30)) &   (sharpe['Sortino Ratio']<=(.97))]
sortino.head()
# Out:
#                                         Fund   mean  Standard Deviation  \
# 0        Aditya Birla Sun Life Tax Relief 96  13.15               13.55
# 1                 Axis Long Term Equity Fund  12.99               12.76
# 2  BOI AXA Tax Advantage Fund - Regular Plan  12.84               15.25
# 3                         DSP Tax Saver Fund  12.55               15.49
# 4              Franklin India Taxshield Fund   8.84               12.24
#
#    Sharpe Ratio  Sortino Ratio  Beta  Alpha  R-Squared Expense Ratio  \
# 0          0.50           0.67  0.88   1.41       0.86          2.27
# 1          0.51           0.71  0.83   1.56       0.86          2.26
# 2          0.42           0.63  0.98   0.53       0.84          3.09
# 3          0.39           0.65  1.04  -0.16       0.93           2.1
# 4          0.20           0.30  0.83  -2.58       0.94          2.08
#
#    1-Year Return    ...        sector1  sector1%     sector2 sector2%  \
# ...

# %%
df['1-Month Return'].describe()
# Out:
# count    17.000000
# mean      3.288824
# std       1.489576
# min      -1.100000
# 25%       2.470000
# 50%       3.530000
# 75%       4.530000
# max       4.930000
# Name: 1-Month Return, dtype: float64

# %%
sip = sortino[ (sortino['1-Month Return']>=(-1.1)) &   (sortino['1-Month Return']<=(4.93))]
sip.head()
# Out:
#                                         Fund   mean  Standard Deviation  \
# 0        Aditya Birla Sun Life Tax Relief 96  13.15               13.55
# 1                 Axis Long Term Equity Fund  12.99               12.76
# 2  BOI AXA Tax Advantage Fund - Regular Plan  12.84               15.25
# 3                         DSP Tax Saver Fund  12.55               15.49
# 4              Franklin India Taxshield Fund   8.84               12.24
#
#    Sharpe Ratio  Sortino Ratio  Beta  Alpha  R-Squared Expense Ratio  \
# 0          0.50           0.67  0.88   1.41       0.86          2.27
# 1          0.51           0.71  0.83   1.56       0.86          2.26
# 2          0.42           0.63  0.98   0.53       0.84          3.09
# 3          0.39           0.65  1.04  -0.16       0.93           2.1
# 4          0.20           0.30  0.83  -2.58       0.94          2.08
#
#    1-Year Return    ...        sector1  sector1%     sector2 sector2%  \
# ...

# %%
cc['Alpha'].describe()
# Out:
# count    17.000000
# mean      0.360588
# std       1.830473
# min      -2.580000
# 25%      -0.710000
# 50%       0.280000
# 75%       0.680000
# max       4.400000
# Name: Alpha, dtype: float64

# %%
alpha = sip[ (sip['Alpha']>=(.36)) &   (sip['Alpha']<=(4.40))]
alpha.head()
# Out:
#                                                  Fund   mean  \
# 0                 Aditya Birla Sun Life Tax Relief 96  13.15
# 1                          Axis Long Term Equity Fund  12.99
# 2           BOI AXA Tax Advantage Fund - Regular Plan  12.84
# 10                             L&T Tax Advantage Fund  12.91
# 11  Motilal Oswal Long Term Equity Fund - Regular ...  15.82
#
#     Standard Deviation  Sharpe Ratio  Sortino Ratio  Beta  Alpha  R-Squared  \
# 0                13.55          0.50           0.67  0.88   1.41       0.86
# 1                12.76          0.51           0.71  0.83   1.56       0.86
# 2                15.25          0.42           0.63  0.98   0.53       0.84
# 10               14.22          0.45           0.66  0.96   0.68       0.94
# 11               13.12          0.71           0.95  0.83   4.40       0.81
#
#    Expense Ratio  1-Year Return    ...        sector1  sector1%       sector2  \
# ...

# %%
cc['R-Squared'].describe()
# Out:
# count    17.000000
# mean      0.894118
# std       0.050381
# min       0.790000
# 25%       0.860000
# 50%       0.900000
# 75%       0.930000
# max       0.960000
# Name: R-Squared, dtype: float64

# %%
rsquare = alpha[ (alpha['R-Squared']>=(.89)) &   (alpha['R-Squared']<=(.96))]
rsquare.head()
# Out:
#                            Fund   mean  Standard Deviation  Sharpe Ratio  \
# 10       L&T Tax Advantage Fund  12.91               14.22          0.45
# 15  Tata India Tax Savings Fund  13.21               15.46          0.44
#
#     Sortino Ratio  Beta  Alpha  R-Squared Expense Ratio  1-Year Return  \
# 10           0.66  0.96   0.68       0.94          2.26          10.35
# 15           0.62  1.02   0.59       0.90           1.7          10.90
#
#       ...       sector1  sector1%       sector2 sector2%       sector3  \
# 10    ...     Financial     25.57  construction    11.51    technology
# 15    ...     Financial     36.42          fmcg    10.41  construction
#
#     sector3%   sector4  sector4%     sector5  sector5%
# 10     10.66  Services      9.87  engneering      8.59
# 15      8.24  Services      7.78      energy      6.76
#
# [2 rows x 94 columns]

# %%
rsquare.shape
# Out:
# (2, 94)

# %%
cc['Standard Deviation'].describe()
# Out:
# count    17.000000
# mean     14.674118
# std       1.440816
# min      12.240000
# 25%      13.550000
# 50%      14.860000
# 75%      15.490000
# max      17.630000
# Name: Standard Deviation, dtype: float64

# %%
std = rsquare[ (rsquare['Standard Deviation']>(12.24)) &   (rsquare['Standard Deviation']<(17.63))]
std.head()
# Out:
#                                         Fund   mean  Standard Deviation  \
# 0        Aditya Birla Sun Life Tax Relief 96  13.15               13.55
# 1                 Axis Long Term Equity Fund  12.99               12.76
# 2  BOI AXA Tax Advantage Fund - Regular Plan  12.84               15.25
# 3                         DSP Tax Saver Fund  12.55               15.49
# 5                 HSBC Tax Saver Equity Fund  11.21               15.88
#
#    Sharpe Ratio  Sortino Ratio  Beta  Alpha  R-Squared Expense Ratio  \
# 0          0.50           0.67  0.88   1.41       0.86          2.27
# 1          0.51           0.71  0.83   1.56       0.86          2.26
# 2          0.42           0.63  0.98   0.53       0.84          3.09
# 3          0.39           0.65  1.04  -0.16       0.93           2.1
# 5          0.30           0.45  1.07  -1.66       0.93          2.39
#
#    1-Year Return    ...        sector1  sector1%       sector2 sector2%  \
# ...

# %%
cc['Beta'].describe()
# Out:
# count    17.000000
# mean      0.969412
# std       0.104431
# min       0.830000
# 25%       0.880000
# 50%       0.980000
# 75%       1.020000
# max       1.190000
# Name: Beta, dtype: float64

# %%
beta = std[ (std['Beta']>(.83)) &   (std['Beta']<(1.19))]
beta.sort_values(by='mean',ascending=False)
# Out:
#                                              Fund   mean  Standard Deviation  \
# 0             Aditya Birla Sun Life Tax Relief 96  13.15               13.55
# 10                         L&T Tax Advantage Fund  12.91               14.22
# 16          Taurus Tax Shield Fund - Regular Plan  12.86               14.86
# 2       BOI AXA Tax Advantage Fund - Regular Plan  12.84               15.25
# 3                              DSP Tax Saver Fund  12.55               15.49
# 9                                JM Tax Gain Fund  12.42               14.86
# 7   IDFC Tax Advantage (ELSS) Fund - Regular Plan  11.90               15.58
# 5                      HSBC Tax Saver Equity Fund  11.21               15.88
# 14               Sundaram Diversified Equity Fund  11.07               16.47
#
#     Sharpe Ratio  Sortino Ratio  Beta  Alpha  R-Squared Expense Ratio  \
# 0           0.50           0.67  0.88   1.41       0.86          2.27
# ...

# %%
beta.sort_values(by='1-Month Return',ascending=False).head()
# Out:
#                                              Fund   mean  Standard Deviation  \
# 0             Aditya Birla Sun Life Tax Relief 96  13.15               13.55
# 3                              DSP Tax Saver Fund  12.55               15.49
# 14               Sundaram Diversified Equity Fund  11.07               16.47
# 16          Taurus Tax Shield Fund - Regular Plan  12.86               14.86
# 7   IDFC Tax Advantage (ELSS) Fund - Regular Plan  11.90               15.58
#
#     Sharpe Ratio  Sortino Ratio  Beta  Alpha  R-Squared Expense Ratio  \
# 0           0.50           0.67  0.88   1.41       0.86          2.27
# 3           0.39           0.65  1.04  -0.16       0.93           2.1
# 14          0.28           0.42  1.10  -2.01       0.92          2.26
# 16          0.43           0.66  1.01   0.33       0.95           2.8
# 7           0.35           0.51  1.02  -0.71       0.89          2.33
#
#     1-Year Return    ...        sector1  sector1%     sector2 sector2%  \
# ...

# %% [markdown]
# The Sortino ratio variation of the Sharpe ratio only factors in downside, or negative volatility, rather than the total volatility used in calculating the Sharpe ratio. The theory behind the Sortino variation is that upside volatility is a plus for the investment, and it therefore should not be included in the risk calculation. Therefore, the Sortino ratio takes upside volatility out of the equation and uses only the downside standard deviation in its calculation instead of the total standard deviation that is used in calculating the Sharpe ratio.
# Analysts commonly prefer to use the Sharpe ratio to evaluate low-volatility investment portfolios and the Sortino variation to evaluate high-volatility portfolios.
# Sortino ratio overcomes the limitation of Sharpe ratio by penalising only downside volatility. It incorporates an investor’s target or threshold return in both numerator and denominator. However, the ratio is not free of limitations. The threshold return is prone to personal bias. Investors may have varied minimum threshold returns and different MARs will give different values of the Sortino ratio. Besides, there are several variatio ..
