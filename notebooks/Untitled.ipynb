# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('c:/users/HP/Downloads/gilt.csv')
df.head()
# Out:
#      Fund type                                   Fund Name   mean  \
# 0  glit funds                    ICICI Prudential Gilt Fund  8.26
# 1  glit funds                DSP Government Securities Fund  7.06
# 2  glit funds          Kotak Gilt Investment - Regular Plan  6.91
# 3  glit funds                                 JM G-Sec Fund  6.96
# 4  glit funds   Canara Robeco Gilt 1988 Fund - Regular Plan  7.77
#
#    Standard Deviation  Sharpe Ratio  Sortino Ratio  Beta  Alpha Expense Ratio  \
# 0                6.59          0.28           0.51  1.17   1.10         0.90%
# 1                5.36          0.11           0.19  0.94   0.04         1.39%
# 2                5.90          0.08           0.14  1.05  -0.18         1.44%
# 3                5.78          0.09           0.18  1.01  -0.10         0.00%
# 4                5.46          0.24           0.54  0.94   0.75         1.25%
#
#    R Square    ...      1999-2001 2001-2003 2003-2005  2005-2007  2007-2009  \
# ...

# %%
df.columns
# Out:
# Index(['Fund type', 'Fund Name ', 'mean', 'Standard Deviation', 'Sharpe Ratio',
#        'Sortino Ratio', 'Beta', 'Alpha', 'Expense Ratio', 'R Square',
#        'Treynor Ratio', 'Lumpsum(Yes/No)', 'SIP (Yes/No)', '1999-2001',
#        '2001-2003', '2003-2005', '2005-2007', '2007-2009', '2009-2011',
#        '2011-2013', '2013-2015', '2015-2017', '2017-2018'],
#       dtype='object')

# %%
df1 = df[['Fund type', 'Fund Name ', 'mean', 'Standard Deviation', 'Sharpe Ratio','Sortino Ratio', 'Beta', 'Alpha', 'Expense Ratio', 'R Square',
       'Treynor Ratio', 'Lumpsum(Yes/No)', 'SIP (Yes/No)']]

# %%
df1.head()
# Out:
#      Fund type                                   Fund Name   mean  \
# 0  glit funds                    ICICI Prudential Gilt Fund  8.26
# 1  glit funds                DSP Government Securities Fund  7.06
# 2  glit funds          Kotak Gilt Investment - Regular Plan  6.91
# 3  glit funds                                 JM G-Sec Fund  6.96
# 4  glit funds   Canara Robeco Gilt 1988 Fund - Regular Plan  7.77
#
#    Standard Deviation  Sharpe Ratio  Sortino Ratio  Beta  Alpha Expense Ratio  \
# 0                6.59          0.28           0.51  1.17   1.10         0.90%
# 1                5.36          0.11           0.19  0.94   0.04         1.39%
# 2                5.90          0.08           0.14  1.05  -0.18         1.44%
# 3                5.78          0.09           0.18  1.01  -0.10         0.00%
# 4                5.46          0.24           0.54  0.94   0.75         1.25%
#
#    R Square  Treynor Ratio Lumpsum(Yes/No) SIP (Yes/No)
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 13 columns):
# Fund type             9 non-null object
# Fund Name             9 non-null object
# mean                  9 non-null float64
# Standard Deviation    9 non-null float64
# Sharpe Ratio          9 non-null float64
# Sortino Ratio         9 non-null float64
# Beta                  9 non-null float64
# Alpha                 9 non-null float64
# Expense Ratio         9 non-null object
# R Square              9 non-null float64
# Treynor Ratio         9 non-null float64
# Lumpsum(Yes/No)       9 non-null object
# SIP (Yes/No)          9 non-null object
# dtypes: float64(8), object(5)
# memory usage: 1016.0+ bytes

# %%
df1.isnull().sum()
# Out:
# Fund type             0
# Fund Name             0
# mean                  0
# Standard Deviation    0
# Sharpe Ratio          0
# Sortino Ratio         0
# Beta                  0
# Alpha                 0
# Expense Ratio         0
# R Square              0
# Treynor Ratio         0
# Lumpsum(Yes/No)       0
# SIP (Yes/No)          0
# dtype: int64

# %%
df1['Expense Ratio'] = pd.to_numeric(df1['Expense Ratio'].str.replace('%', ''))
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
import numpy as np

# %%
df1.describe()
# Out:
#            mean  Standard Deviation  Sharpe Ratio  Sortino Ratio      Beta  \
# count  9.000000            9.000000      9.000000       9.000000  9.000000
# mean   7.134444            5.811111      0.120000       0.250000  1.017778
# std    1.049561            0.667972      0.175428       0.338711  0.135442
# min    5.380000            5.000000     -0.150000      -0.250000  0.830000
# 25%    6.910000            5.360000      0.080000       0.140000  0.940000
# 50%    7.060000            5.780000      0.110000       0.190000  1.010000
# 75%    7.910000            6.230000      0.280000       0.510000  1.100000
# max    8.270000            6.920000      0.290000       0.700000  1.240000
#
#           Alpha  Expense Ratio  R Square  Treynor Ratio
# count  9.000000       9.000000  9.000000       9.000000
# mean   0.068889       1.135556  0.922222       0.878889
# std    1.061690       0.499277  0.038333       1.005466
# min   -1.820000       0.000000  0.840000      -0.860000
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 13 columns):
# Fund type             9 non-null object
# Fund Name             9 non-null object
# mean                  9 non-null float64
# Standard Deviation    9 non-null float64
# Sharpe Ratio          9 non-null float64
# Sortino Ratio         9 non-null float64
# Beta                  9 non-null float64
# Alpha                 9 non-null float64
# Expense Ratio         9 non-null float64
# R Square              9 non-null float64
# Treynor Ratio         9 non-null float64
# Lumpsum(Yes/No)       9 non-null object
# SIP (Yes/No)          9 non-null object
# dtypes: float64(9), object(4)
# memory usage: 1016.0+ bytes

# %%
corrmat = df1.corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corrmat,annot=True)
plt.show()

# %%
corrmat.sort_values(by='mean',ascending=False).mean
# Out:
# <bound method DataFrame.mean of                         mean  Standard Deviation  Sharpe Ratio  Sortino Ratio  \
# mean                1.000000           -0.060861      0.991121       0.954120
# Alpha               0.997014           -0.137393      0.990536       0.962442
# Sharpe Ratio        0.991121           -0.084165      1.000000       0.981161
# Sortino Ratio       0.954120           -0.185028      0.981161       1.000000
# Treynor Ratio       0.921961            0.042586      0.951956       0.943991
# Standard Deviation -0.060861            1.000000     -0.084165      -0.185028
# Beta               -0.106672            0.995790     -0.136783      -0.246591
# R Square           -0.320597            0.749728     -0.386632      -0.533352
# Expense Ratio      -0.392236            0.141207     -0.382904      -0.379707
#
#                         Beta     Alpha  Expense Ratio  R Square  Treynor Ratio
# mean               -0.106672  0.997014      -0.392236 -0.320597       0.921961
# ...

# %%
df.columns
# Out:
# Index(['Fund type', 'Fund Name ', 'mean', 'Standard Deviation', 'Sharpe Ratio',
#        'Sortino Ratio', 'Beta', 'Alpha', 'Expense Ratio', 'R Square',
#        'Treynor Ratio', 'Lumpsum(Yes/No)', 'SIP (Yes/No)', '1999-2001',
#        '2001-2003', '2003-2005', '2005-2007', '2007-2009', '2009-2011',
#        '2011-2013', '2013-2015', '2015-2017', '2017-2018'],
#       dtype='object')

# %%
plt.figure(figsize=(20,5))
sns.pointplot(df['Fund Name '].values,df['mean'].values,color='green')
sns.pointplot(df['Fund Name '].values,df['Treynor Ratio'].values,color='red')
plt.xticks(rotation=90)
plt.show()

# %%
sns.set(style="ticks", color_codes=True)

# %%
plt.figure(figsize=(5,5))
sns.pairplot(data=df1,hue='mean',kind='scatter')
plt.show()
