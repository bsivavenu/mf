# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('df1.csv')
data.head()
# Out:
#                                       Fund me    Mean  standard deviation  \
# 0                     Reliance ETF Junior BeES  13.77               16.00
# 1       DSP Top 100 Equity Fund - Regular Plan   9.54               14.98
# 2  Aditya Birla Sun Life Frontline Equity Fund  10.51               13.30
# 3                   HSBC Large Cap Equity Fund  11.78               14.84
# 4                 Franklin India Bluechip Fund   8.52               12.83
#
#    sharpe  sortino  beta  Alpha  R square  Treynor ratio  Expense Ratio  \
# 0    0.46     0.83  0.96   2.21      0.69          10.26         0.0023
# 1    0.21     0.34  1.02  -2.38      0.89           5.58         0.0218
# 2    0.31     0.48  0.93  -0.90      0.75          19.37         2.1800
# 3    0.36     0.58  1.04  -0.23      0.92          20.11         2.2100
# 4    0.16     0.30  0.90  -2.75      0.94           6.00         2.0600
#
#    Min Investment Amt.  SIP ( YES/NO) Lumpsum(Yes/No)        V AUM ( CR )
# ...

# %%
data.shape
# Out:
# (83, 15)

# %%
data.describe()
# Out:
#             Mean  standard deviation     sharpe    sortino       beta  \
# count  83.000000           83.000000  83.000000  83.000000  83.000000
# mean    9.107686            8.840912   0.719639   1.405060   1.265060
# std     4.990087            7.763522   0.945853   2.204344   0.960002
# min    -0.900000            0.110200  -0.460000  -0.670000   0.340000
# 25%     6.945000            1.065000   0.210000   0.335000   0.800000
# 50%     7.900000            6.590000   0.430000   0.700000   0.950000
# 75%    12.030000           16.445000   0.865000   1.145000   1.100000
# max    23.850000           22.480000   3.410000   8.890000   5.510000
#
#            Alpha   R square  Treynor ratio  Expense Ratio  \
# count  83.000000  83.000000      83.000000      83.000000
# mean    2.308258   0.795904       5.194111       0.929569
# std     3.859905   0.982996       6.512457       1.126977
# min    -4.840000   0.080000     -10.030000       0.001200
# ...

# %%
data.columns
# Out:
# Index(['Fund me ', 'Mean', 'standard deviation', 'sharpe', 'sortino', 'beta',
#        'Alpha', 'R square', 'Treynor ratio', 'Expense Ratio',
#        'Min Investment Amt. ', 'SIP ( YES/NO)', 'Lumpsum(Yes/No)', 'V',
#        'AUM ( CR )'],
#       dtype='object')

# %%
cols = data.columns[1:10]
# Out:
# Index(['Mean', 'standard deviation', 'sharpe', 'sortino', 'beta', 'Alpha',
#        'R square', 'Treynor ratio', 'Expense Ratio'],
#       dtype='object')

# %%
data_metrics = data[cols]
data_metrics.head(2)
# Out:
#     Mean  standard deviation  sharpe  sortino  beta  Alpha  R square  \
# 0  13.77               16.00    0.46     0.83  0.96   2.21      0.69
# 1   9.54               14.98    0.21     0.34  1.02  -2.38      0.89
#
#    Treynor ratio  Expense Ratio
# 0          10.26         0.0023
# 1           5.58         0.0218

# %%
corrmat = data_metrics.corr().sort_values('Mean',ascending=False).Mean
# Out:
# Mean                  1.000000
# Treynor ratio         0.805168
# standard deviation    0.650459
# Expense Ratio         0.542492
# Alpha                 0.244756
# R square              0.125610
# sharpe                0.033312
# sortino              -0.031568
# beta                 -0.132317
# Name: Mean, dtype: float64

# %%
plt.figure(figsize=(8,8))
sns.heatmap(corrmat,annot=True)
plt.show()

# %%
data.columns
# Out:
# Index(['Fund me ', 'Mean', 'standard deviation', 'sharpe', 'sortino', 'beta',
#        'Alpha', 'R square', 'Treynor ratio', 'Expense Ratio',
#        'Min Investment Amt. ', 'SIP ( YES/NO)', 'Lumpsum(Yes/No)', 'V',
#        'AUM ( CR )'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 15 columns):
# Fund me                 83 non-null object
# Mean                    83 non-null float64
# standard deviation      83 non-null float64
# sharpe                  83 non-null float64
# sortino                 83 non-null float64
# beta                    83 non-null float64
# Alpha                   83 non-null float64
# R square                83 non-null float64
# Treynor ratio           83 non-null float64
# Expense Ratio           83 non-null float64
# Min Investment Amt.     83 non-null int64
# SIP ( YES/NO)           83 non-null object
# Lumpsum(Yes/No)         83 non-null object
# V                       83 non-null object
# AUM ( CR )              83 non-null object
# dtypes: float64(9), int64(1), object(5)
# memory usage: 9.8+ KB

# %%
high_risk_trenor = data[(data['Treynor ratio'].values > (data['Treynor ratio'].mean())) & (data['Treynor ratio'].values < (data['Treynor ratio'].max()))]

# %%
high_risk_trenor.head()
# Out:
#                                              Fund me      Mean  \
# 0                            Reliance ETF Junior BeES  13.7700
# 1              DSP Top 100 Equity Fund - Regular Plan   9.5400
# 2         Aditya Birla Sun Life Frontline Equity Fund  10.5100
# 3                          HSBC Large Cap Equity Fund  11.7800
# 4                        Franklin India Bluechip Fund   8.5200
# 5                  Tata Large Cap Fund - Regular Plan   0.1163
# 6                           L&T EMERGES BUSINESS FUND  20.3400
# 7                                  sbi small cap fund  18.0300
# 8                           Reliance Small Cap Fund    18.1400
# 10                 DSP Small Cap Fund - Regular Plan   12.2800
# 11              Kotak Small Cap Fund - Regular Plan    11.6500
# 12               HDFC Small Cap Fund - Regular Plan    18.3400
# 13            Franklin India Smaller Companies Fund    13.1900
# 14                       HSBC Small Cap Equity Fund    10.7400
# ...

# %%
data['standard deviation'].describe()
# Out:
# count    83.000000
# mean      8.840912
# std       7.763522
# min       0.110200
# 25%       1.065000
# 50%       6.590000
# 75%      16.445000
# max      22.480000
# Name: standard deviation, dtype: float64

# %%
std_consistency =  high_risk_trenor[(high_risk_trenor['standard deviation'] >(0)) & (high_risk_trenor['standard deviation'] < (22.48))]

# %%
std_consistency.head()
# Out:
#                                       Fund me    Mean  standard deviation  \
# 0                     Reliance ETF Junior BeES  13.77               16.00
# 1       DSP Top 100 Equity Fund - Regular Plan   9.54               14.98
# 2  Aditya Birla Sun Life Frontline Equity Fund  10.51               13.30
# 3                   HSBC Large Cap Equity Fund  11.78               14.84
# 4                 Franklin India Bluechip Fund   8.52               12.83
#
#    sharpe  sortino  beta  Alpha  R square  Treynor ratio  Expense Ratio  \
# 0    0.46     0.83  0.96   2.21      0.69          10.26         0.0023
# 1    0.21     0.34  1.02  -2.38      0.89           5.58         0.0218
# 2    0.31     0.48  0.93  -0.90      0.75          19.37         2.1800
# 3    0.36     0.58  1.04  -0.23      0.92          20.11         2.2100
# 4    0.16     0.30  0.90  -2.75      0.94           6.00         2.0600
#
#    Min Investment Amt.  SIP ( YES/NO) Lumpsum(Yes/No)        V AUM ( CR )
# ...
